# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

train_data = pd.read_csv('/content/drive/My Drive/cure_the_princess_train.csv')
val_data = pd.read_csv('/content/drive/My Drive/cure_the_princess_validation.csv')
test_data = pd.read_csv('/content/drive/My Drive/cure_the_princess_test.csv')

# %%
# %%timeit


# Rastgele sayı üreteci ayarla
SEED = 180401027
torch.manual_seed(SEED)
from sklearn.preprocessing import MinMaxScaler,RobustScaler
skaler = MinMaxScaler()
# Verileri tensor'lara dönüştür
train_X = torch.tensor(train_data.values[:, :-1], dtype=torch.float32)
train_X = torch.tensor(skaler.fit_transform(train_X),dtype=torch.float32)
train_y = torch.tensor(train_data.values[:, -1], dtype=torch.float32)
val_X = torch.tensor(val_data.values[:, :-1], dtype=torch.float32)
val_X = torch.tensor(skaler.fit_transform(val_X),dtype=torch.float32)
val_y = torch.tensor(val_data.values[:, -1], dtype=torch.float32)
test_X = torch.tensor(test_data.values[:, :-1], dtype=torch.float32)
test_X = torch.tensor(skaler.fit_transform(test_X),dtype=torch.float32)
test_y = torch.tensor(test_data.values[:, -1], dtype=torch.float32)
train_y = train_y.reshape(-1, 1)
test_y = test_y.reshape(-1, 1)
val_y = val_y.reshape(-1, 1)
# Out:
# 2.16 ms ± 271 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# time: 17.5 s (started: 2023-04-12 13:49:31 +00:00)

# %%
# !pip install ipython-autotime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.1-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (67.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (2.14.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->ipython-autotime) (3.0.38)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.6)
# Installing collected packages: jedi, ipython-autotime
# Successfully installed ipython-autotime-0.3.1 jedi-0.18.2

# %%
# %load_ext autotime
# MLP modelini tanımla
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt



# Rastgele sayı üreteci ayarla
SEED = 180401027
torch.manual_seed(SEED)
from sklearn.preprocessing import MinMaxScaler,RobustScaler
skaler = MinMaxScaler()
# Verileri tensor'lara dönüştür
train_X = torch.tensor(train_data.values[:, :-1], dtype=torch.float32)
train_X = torch.tensor(skaler.fit_transform(train_X),dtype=torch.float32)
train_y = torch.tensor(train_data.values[:, -1], dtype=torch.float32)
val_X = torch.tensor(val_data.values[:, :-1], dtype=torch.float32)
val_X = torch.tensor(skaler.fit_transform(val_X),dtype=torch.float32)
val_y = torch.tensor(val_data.values[:, -1], dtype=torch.float32)
test_X = torch.tensor(test_data.values[:, :-1], dtype=torch.float32)
test_X = torch.tensor(skaler.fit_transform(test_X),dtype=torch.float32)
test_y = torch.tensor(test_data.values[:, -1], dtype=torch.float32)
train_y = train_y.reshape(-1, 1)
test_y = test_y.reshape(-1, 1)
val_y = val_y.reshape(-1, 1)
class MLP(nn.Module):
    def __init__(self, input_size, hidden_size1, hidden_size2, output_size):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size1)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size1, hidden_size2)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size2, output_size)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu1(out)
        out = self.fc2(out)
        out = self.relu2(out)
        out = self.fc3(out)
        out = self.sigmoid(out)
        return out

# Modeli eğit
input_size = train_X.shape[1]
hidden_size1 = 100
hidden_size2 = 50
output_size = 1

model = MLP(input_size, hidden_size1, hidden_size2, output_size)

criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)
batch_size = 16
num_epochs = 700
patience = 10

# Eğitim ve doğrulama seti için kayıp değerlerini tutacak listeleri oluştur
train_loss_list = []
val_loss_list = []
best_val_loss=None
patience_counter=0
# Eğitim döngüsü
for epoch in range(num_epochs):
    # Batch'lerden eğitim kayıplarını tutacak bir liste oluştur
    epoch_train_loss = []
    for i in range(0, len(train_X), batch_size):
        inputs = train_X[i:i+batch_size]
        labels = train_y[i:i+batch_size].reshape(-1, 1)

        optimizer.zero_grad()

        outputs = model(inputs)

        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()

        # Batch kaybını ekle
        epoch_train_loss.append(loss.item())

    # Eğitim kaybını epoch sonunda hesapla ve listeye ekle
    train_loss = np.mean(epoch_train_loss)
    train_loss_list.append(train_loss)

 # Doğrulama kaybını hesapla ve listeye ekle
    val_loss = 0.0
    """val_correct = 0.0
    val_total = 0.0"""
    #validation_count = 0.0
    with torch.no_grad():
        model.eval()
        for validation_X, validation_y in zip(val_X,val_y):
            outputs = model(validation_X)
            loss = criterion(outputs, validation_y)
            #validation_count += 1.0
            val_loss += loss.item()
            """, predicted = torch.max(outputs, 1) # burada validation accuracy hesabı var.
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()"""

    model.train()

    # calculate metrics
  
    val_loss /= val_X.shape[0]

    #val_acc = 100 * val_correct / val_total

    print("Epoch", epoch, "Training loss", train_loss,"Validation Loss :",val_loss)

    
    val_loss_list.append(val_loss)

    val_score = val_loss
    
    if best_val_loss is None:
        best_val_loss = val_score # hafızada patience boyu tutmaya başla
        torch.save(model.state_dict(), "checkpoint.pt")
    elif best_val_loss < val_score: # patience counter
        patience_counter += 1
        print("Earlystopping Patience Counter:",patience_counter)
        if patience_counter == patience:
            break
    else:
        best_val_loss = val_score
        torch.save(model.state_dict(), "checkpoint.pt") # to keep the best model
        patience_counter = 0
plt.plot(train_loss_list, label="Training loss")
plt.plot(val_loss_list, label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()


print('Finished Training')
model = MLP(input_size, hidden_size1, hidden_size2, output_size)
model.load_state_dict(torch.load('checkpoint.pt'))
model.eval()
predicts =[]
real_labels = list()
with torch.no_grad():
    for inputs,label in zip(test_X,test_y):
        outputs = model(inputs)
        predict = round(float(outputs.data))
        predicts.append(predict)


        real_labels.extend(label.tolist())
from sklearn.metrics import f1_score,accuracy_score,classification_report
print("Accuracy score of this model: {}".format(accuracy_score(real_labels,predicts)))
print(classification_report(real_labels,predicts))
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# Epoch 0 Training loss 0.6919747093055821 Validation Loss : 0.6917834392019139
# Epoch 1 Training loss 0.6911305091049098 Validation Loss : 0.6907961524216233
# Epoch 2 Training loss 0.6902790348741072 Validation Loss : 0.6898320565937431
# Epoch 3 Training loss 0.689421317999876 Validation Loss : 0.6888623645730839
# Epoch 4 Training loss 0.6885415436346319 Validation Loss : 0.6878431401434978
# Epoch 5 Training loss 0.687621619882463 Validation Loss : 0.6867471846045962
# Epoch 6 Training loss 0.6866438909421994 Validation Loss : 0.68554349044326
# Epoch 7 Training loss 0.6855824393562123 Validation Loss : 0.6842208990625515
# Epoch 8 Training loss 0.6844296862807455 Validation Loss : 0.6827715320192325
# Epoch 9 Training loss 0.6831592668460894 Validation Loss : 0.6811750369846441
# Epoch 10 Training loss 0.6817547867569742 Validation Loss : 0.6794134420194443
# Epoch 11 Training loss 0.6802050033702126 Validation Loss : 0.6774794428971163
# Epoch 12 Training loss 0.6784807768049119 Validation Loss : 0.6753413419055331
# Epoch 13 Training loss 0.6765784002557585 Validation Loss : 0.6729334666850461
# Epoch 280 Training loss 0.09447127557064913 Validation Loss : 0.14178381631016482
# Earlystopping Patience Counter: 1
# Epoch 281 Training loss 0.09415031738484962 Validation Loss : 0.14163409373069427
# Earlystopping Patience Counter: 2
# Epoch 282 Training loss 0.09379037345842092 Validation Loss : 0.14080031979245972
# Epoch 283 Training loss 0.09349121518810338 Validation Loss : 0.141451753576676
# Earlystopping Patience Counter: 1
# Epoch 284 Training loss 0.09326154176334414 Validation Loss : 0.14049693485896883
# Epoch 285 Training loss 0.09285644368751894 Validation Loss : 0.14096044720675058
# Earlystopping Patience Counter: 1
# Epoch 286 Training loss 0.09264266160847265 Validation Loss : 0.14074592972985575
# Earlystopping Patience Counter: 2
# Epoch 287 Training loss 0.0922411643911766 Validation Loss : 0.1405734595504636
# Earlystopping Patience Counter: 3
# Epoch 288 Training loss 0.0921499493614405 Validation Loss : 0.14003808467125045
# Epoch 289 Training loss 0.09163717696844023 Validation Loss : 0.14025683719181659
# Earlystopping Patience Counter: 1
# Epoch 290 Training loss 0.09147759274685685 Validation Loss : 0.14055845091285904
# Earlystopping Patience Counter: 2
# Epoch 291 Training loss 0.09122205887555698 Validation Loss : 0.1396636642398867
# Epoch 292 Training loss 0.09097139070494266 Validation Loss : 0.14040481832267335
# Earlystopping Patience Counter: 1
# Epoch 293 Training loss 0.09066091015746322 Validation Loss : 0.1402053324684225
# Earlystopping Patience Counter: 2
# Epoch 294 Training loss 0.0903744027254325 Validation Loss : 0.13977630323968698
# Earlystopping Patience Counter: 3
# Epoch 295 Training loss 0.09015777987675576 Validation Loss : 0.14007134075623712
# Earlystopping Patience Counter: 4
# Epoch 296 Training loss 0.08975107043604308 Validation Loss : 0.14019125875549646
# Earlystopping Patience Counter: 5
# Epoch 297 Training loss 0.08958614208511537 Validation Loss : 0.1401183414978932
# Earlystopping Patience Counter: 6
# Epoch 298 Training loss 0.08929714726732124 Validation Loss : 0.1394535324921467
# Epoch 299 Training loss 0.08909966273209717 Validation Loss : 0.14033363868094012
# Earlystopping Patience Counter: 1
# Epoch 300 Training loss 0.0887693576396832 Validation Loss : 0.13982019308550542
# Earlystopping Patience Counter: 2
# Epoch 301 Training loss 0.08855071637920942 Validation Loss : 0.13987200442073527
# Earlystopping Patience Counter: 3
# Epoch 302 Training loss 0.08856493910137989 Validation Loss : 0.13960565428073393
# Earlystopping Patience Counter: 4
# Epoch 303 Training loss 0.087891458675171 Validation Loss : 0.13976036253345114
# Earlystopping Patience Counter: 5
# Epoch 304 Training loss 0.08792253716884157 Validation Loss : 0.13976099544051604
# Earlystopping Patience Counter: 6
# Epoch 305 Training loss 0.08744417397376103 Validation Loss : 0.1395436646757947
# Earlystopping Patience Counter: 7
# Epoch 306 Training loss 0.08729488479232864 Validation Loss : 0.13971261402285426
# Earlystopping Patience Counter: 8
# Epoch 307 Training loss 0.08716511037908023 Validation Loss : 0.13896475366557012
# Epoch 308 Training loss 0.0867708212448449 Validation Loss : 0.1394889559493179
# Earlystopping Patience Counter: 1
# Epoch 309 Training loss 0.08657177759310868 Validation Loss : 0.13915066560557474
# Earlystopping Patience Counter: 2
# Epoch 310 Training loss 0.08627314293827815 Validation Loss : 0.13860052054855376
# Epoch 311 Training loss 0.08606898435686208 Validation Loss : 0.1392240480378773
# Earlystopping Patience Counter: 1
# Epoch 312 Training loss 0.08573342901006152 Validation Loss : 0.1390812109785805
# Earlystopping Patience Counter: 2
# Epoch 313 Training loss 0.08560003283657605 Validation Loss : 0.1388895370536486
# Earlystopping Patience Counter: 3
# Epoch 314 Training loss 0.08539443070516933 Validation Loss : 0.13828129327220412
# Epoch 315 Training loss 0.08501409423313563 Validation Loss : 0.13881696100879304
# Earlystopping Patience Counter: 1
# Epoch 316 Training loss 0.08481233957211805 Validation Loss : 0.1384546710680952
# Earlystopping Patience Counter: 2
# Epoch 317 Training loss 0.08457556567331657 Validation Loss : 0.13890464727657587
# Earlystopping Patience Counter: 3
# Epoch 318 Training loss 0.08444757923436692 Validation Loss : 0.13861389995152903
# Earlystopping Patience Counter: 4
# Epoch 319 Training loss 0.08423290306207122 Validation Loss : 0.13764073997375678
# Epoch 320 Training loss 0.08388693839358756 Validation Loss : 0.13878207690563774
# Earlystopping Patience Counter: 1
# Epoch 321 Training loss 0.08381512928518313 Validation Loss : 0.13858957277838532
# Earlystopping Patience Counter: 2
# Epoch 322 Training loss 0.08346862469717295 Validation Loss : 0.13852808126187377
# Earlystopping Patience Counter: 3
# Epoch 323 Training loss 0.08332222553936741 Validation Loss : 0.1386725143299564
# Earlystopping Patience Counter: 4
# Epoch 324 Training loss 0.08299703014236462 Validation Loss : 0.13749905980566765
# Epoch 325 Training loss 0.0828585350249387 Validation Loss : 0.13843755514196404
# Earlystopping Patience Counter: 1
# Epoch 326 Training loss 0.0825619784101278 Validation Loss : 0.1386300410363233
# Earlystopping Patience Counter: 2
# Epoch 327 Training loss 0.08233016096291286 Validation Loss : 0.13833389671754437
# Earlystopping Patience Counter: 3
# Epoch 328 Training loss 0.08205558826463132 Validation Loss : 0.13835524307022168
# Earlystopping Patience Counter: 4
# Epoch 329 Training loss 0.08191267626147859 Validation Loss : 0.1384175472613923
# Earlystopping Patience Counter: 5
# Epoch 330 Training loss 0.0817820156535393 Validation Loss : 0.13793580282732856
# Earlystopping Patience Counter: 6
# Epoch 331 Training loss 0.08145489658028641 Validation Loss : 0.13857607756160845
# Earlystopping Patience Counter: 7
# Epoch 332 Training loss 0.08149391240617142 Validation Loss : 0.13756622687688083
# Earlystopping Patience Counter: 8
# Epoch 333 Training loss 0.08114946448491721 Validation Loss : 0.13842063854987754
# Earlystopping Patience Counter: 9
# Epoch 334 Training loss 0.08099781672317016 Validation Loss : 0.13879429060884
# Earlystopping Patience Counter: 10
# Finished Training
# Accuracy score of this model: 0.9507772020725389
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.97      0.95       384
#          1.0       0.97      0.93      0.95       388
#
#     accuracy                           0.95       772
#    macro avg       0.95      0.95      0.95       772
# weighted avg       0.95      0.95      0.95       772
#
# time: 27.7 s (started: 2023-04-12 13:52:02 +00:00)
